# %% [markdown]
# # En notebook for å lage clustre fra kollokasjoner
#
# Ord kan dann clustre via en kollokasjonsanalyse. Her litt engelsk forklaring:
#
# The term collocation has traditionally been restricted to words that are juxtaposed together as phrases like “strong coffee”, “strict regime” or “eat dinner”. Here we take collocations to be realized as skipgrams, or as word pairs that simply cooccur within a context which in itself is a contiguous sequence of words, typically a paragraph or a window of n words around a given word. Juxtaposed collocates will also be part of the result set.
#
# The collocates for W is the words that are associated with W based on a measure of association. The purpose of such a measure for a word W (e.g. “democracy”) is to provide a means of collecting associated words in the discourses in which W occurs within C. Collocations can be viewed as collecting discourse markers for W, in the sense that the collocates are uttered (written or spoken) together with W. The collocates for W are computed via an association measure on the set of all cooccurrent words.

# %% [markdown]
# Start med å importere de kommandoene som trengs fra nbtext

# %%
from module_update import update
# Out:
# Updated file nbtext.py
# Updated file nbpictures.py

# %%
import nbtext as nb
from nbtext import cloud, get_urn, Cluster, Corpus
# %matplotlib inline

# %%
words = 'min mitt mine'.split()
nb.collocation_data(words, yearfrom = 1800, yearto = 1780, limit = 1000, before = 1, after = 2, title = '%')
# Out:
# min
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Documents\GitHub\NTNU_oktober_2018\nbtext.py in collocation_data(words, yearfrom, yearto, limit, before, after, title)
#     217
# --> 218             a[word].columns = [word]
#     219
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    4384             object.__getattribute__(self, name)
# -> 4385             return object.__setattr__(self, name, value)
#    4386         except AttributeError:
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     644     def _set_axis(self, axis, labels):
# --> 645         self._data.set_axis(axis, labels)
#     646         self._clear_item_cache()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals.py in set_axis(self, axis, new_labels)
#    3322                 'Length mismatch: Expected axis has {old} elements, new '
# -> 3323                 'values have {new} elements'.format(old=old_len, new=new_len))
#    3324
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 1 elements
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-6-ef612b9bac12> in <module>()
#       1 words = 'min mitt mine'.split()
# ----> 2 nb.collocation_data(words, yearfrom = 1800, yearto = 1780, limit = 1000, before = 1, after = 2, title = '%')
#
# ~\Documents\GitHub\NTNU_oktober_2018\nbtext.py in collocation_data(words, yearfrom, yearto, limit, before, after, title)
#     219
#     220         except:
# --> 221             print(w, ' feilsituasjon')
#     222     b=b.fillna(0)
#     223
#
# UnboundLocalError: local variable 'w' referenced before assignment

# %%
import pandas as pd
from nbtext import collocation

# %%
def collocation_data(words, yearfrom = 2000, yearto = 2005, limit = 1000, before = 5, after = 5, title = '%', corpus='bok'):
    """Collocation for a set of words sum up all the collocations words is a list of words or a blank separated string of words"""
    import sys
    a = dict()
    
    if isinstance(words, str):
        words = words.split()
    
    for word in words:
        
        print(word)
        try:
            
            a[word] = collocation(
                word, 
                yearfrom = yearfrom, yearto = yearto, limit = limit, 
                corpus = corpus, before = before, 
                after = after, title = title
            )
            
            a[word].columns = [word]
        
        except:    
            print(word, ' feilsituasjon', sys.exc_info())
    result = pd.DataFrame()
    for w in a:
        result = result.join(a[w], how='outer')
    return pd.DataFrame(result.sum(axis=1))

# %%
words = 'min mitt mine'.split()
frame = collocation_data(words, yearfrom = 2000, yearto = 2005, limit = 50, before = 1, after = 2, title = '%')
# Out:
# min
# mitt
# mine

# %%
frame
# Out:
#                   0
# !              82.0
# "              16.0
# %               1.0
# '               8.0
# (              27.0
# )              49.0
# *               1.0
# +               2.0
# ,             547.0
# -              45.0
# .             383.0
# ...            15.0
# /              26.0
# 0               2.0
# 0.5             1.0
# 0.75            1.0
# 08              2.0
# 1              10.0
# 10             12.0
# 10,000          1.0
# 106             1.0
# 11              1.0
# 12              1.0
# 135             3.0
# 15             13.0
# 18              2.0
# 18.             1.0
# 180             2.0
# 1989.           1.0
# 2               6.0
# ...             ...
# åssit           1.0
# åt              1.0
# ærbødige        1.0
# ærend           1.0
# ærer            1.0
# öfver           1.0
# øienbryn        1.0
# øjne            1.0
# økte            1.0
# ønske           6.0
# ønsker          1.0
# øre             2.0
# ørene           5.0
# ører            3.0
# øret            5.0
# øversåttning    1.0
# øvrige          1.0
# øye             3.0
# øyenbryn        1.0
# øyet            1.0
# øyne            6.0
# øynene          4.0
# øyner           1.0
# čuodjá          1.0
# —               1.0
# ’               1.0
# “               1.0
# ”               2.0
# •               1.0
# ■               1.0
#
# [2713 rows x 1 columns]
