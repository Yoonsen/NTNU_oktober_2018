# %% [markdown]
# # Undersøk korpus med metadata
#
# Notebook for å undersøke korpus med metadata

# %%
from module_update import update
# Out:
# Updated file nbtext.py
# Updated file nbpictures.py

# %%
import nbtext as nb
import networkx as nx
from nbtext import Corpus
# %matplotlib inline

# %%
update('graph_networkx_louvain')
import graph_networkx_louvain as gnl
# Out:
# Updated file graph_networkx_louvain.py

# %% [markdown]
# Kommandoen for å lage et korpus er *Corpus()* som bygger et korpus av tekster som sammenlignes med en referanse. I det her eksemplet bygges referansen samtidig, men i et ideelt tilfelle kan vi ønske å la referansen være ferdigbygd et sted.

# %%
objekt = Corpus(
    period=(1950, 2010),
    title='%',
    subject='krig',
    ddk='%',
    reference=50,
    max_books=50)

# %% [markdown]
# ## Undersøk forskjeller
#
# Dataene viser forskjellem mellom målkorpus og referanse. Se på differansen med kommandoen *difference* som tar et sett parametre. De viktigste for analysen er *freq_exp* som vekter frekvensen til ordene i målkorpuset, og *doc_exp* som vekter dokumentfrekvensen i målkorpuset.
#
# Settes verdien for *top* lik null får du hele korpuset.

# %%
objekt.difference(top=10, aslist=False, freq_exp=1.1, doc_exp=1.5)
# Out:
#               diff
# krigen    0.030023
# krig      0.027747
# våpen     0.022110
# militære  0.021824
# soldater  0.021747
# var       0.020338
# sivile    0.020311
# angrep    0.019694
# fienden   0.019265
# militær   0.018920

# %%
objekt.difference(top=100)
# Out:
# krigen, krig, soldater, våpen, militære, Irak, britiske, sivile, tyskerne, sårede, soldatene, militær, fienden, styrker, krigens, allierte, hæren, general, Kosovo, forsvar, angrep, kampen, motstand, konflikten, russiske, amerikanske, vestlige, såkalte, styrkene, angrepet, Russland, arabiske, svenska, USA, Hitler, sykehus, makten, offiserer, Byen, kampene, forsvaret, ordre, nordmenn, kanoner, Røde, israelske, forsvare, 1943, bomber, militært, Serbia, Krig, væpnede, tropper, Krigen, Fienden, Vietnam, Erling, serbiske, angripe, britene, parter, Bagdad, overleve, september, amerikansk, Midtøsten, sovjetiske, palestinske, fiende, General, War, ne, muslimske, stridende, nordmennene, un, arabisk, uskyldige, islam, utstyr, lands, krigsfanger, Saddam, offisielle, troppene, Hussein, amerikanerne, fiendens, skutt, kinesiske, svenskene, Europa, arrestert, freden, britisk, fronten, Ali, Bush, Skulle

# %% [markdown]
# Legg til summary() for se litt hva korpuset inneholder

# %%
objekt.summary()
# Out:
# {'parameters': {'year': 1950,
#   'next': 60,
#   'subject': 'krig',
#   'ddk': '%',
#   'author': '%',
#   'title': '%',
#   'limit': 50,
#   'reference': 50},
#  'target_urn': [2014100808099,
#   2009033104068,
#   2008091104061,
#   2013022238100,
#   2013012306042,
#   2012062206079,
#   2014051906067,
#   2011041408059,
#   2008070400048,
#   2016031748053],
#  'reference urn': [2011021020004,
#   2016022409068,
#   2014061308117,
#   2011062808072,
#   2015022308168,
#   2014102108304,
#   2014041106077,
#   2009042104084,
#   2010111208046,
#   2013030506172]}

# %% [markdown]
# # Metadata for korpuset kan raskt sjekkes
#
# Pass på at ikke korpuset er for stort (mange tusen).

# %%
nb.metadata(objekt.target_urn)
# Out:
# [[2014100808099,
#   'Isaksen, Runo',
#   2005,
#   'Litteratur i krig',
#   'Cappelen',
#   'nob',
#   ''],
#  [2009033104068,
#   'Žižek, Slavoj',
#   2002,
#   'Virkelighetens ørken',
#   'Gyldendal',
#   'nob',
#   'eng'],
#  [2008091104061,
#   'Riste, Olav',
#   1997,
#   '"Strengt hemmelig"',
#   'Universitetsforl.',
#   'mul',
#   ''],
#  [2013022238100,
#   'Nordberg, Nils Håkon',
#   2005,
#   'Nordmenn i krig',
#   'Damm',
#   'nob',
#   ''],
#  [2013012306042,
#   'Vachon, Marc',
#   2006,
#   'Rebell uten grenser',
#   'Jentas',
#   'nob',
#   'fre'],
#  [2012062206079,
#   'Rygh, Jan A.',
#   1977,
#   'Tilfluktsrom i praksis',
#   'Ingeniørforl.',
#   'nob',
#   ''],
#  [2014051906067,
#   'Kvasbø, Alf',
#   1995,
#   'Rått farvel',
#   'Pedagogisk psykologisk forl.',
#   'nob',
#   ''],
#  [2011041408059,
#   'Tamelander, Michael',
#   2004,
#   'D-dagen',
#   'Spartacus',
#   'nob',
#   'swe'],
#  [2008070400048,
#   '',
#   1996,
#   '"O sørgelig\' tider! O trengende stand!"',
#   'Norsk folkeminnelag;Aschehoug',
#   'mul',
#   ''],
#  [2016031748053,
#   'Frognes, Dag Reidar',
#   2000,
#   'Tordenskiold',
#   'Omnipax',
#   'nob',
#   ''],
#  [2014120807606,
#   'Hyldmo, Egil',
#   2008,
#   'Våre heimland',
#   'Ego media',
#   'nno',
#   ''],
#  [2014101408066,
#   'Nafisi, Azar',
#   2004,
#   'Å lese Lolita i Teheran',
#   'Humanist forl.',
#   'nob',
#   'eng'],
#  [2011050508008,
#   'Krag, H.P.S.',
#   2003,
#   'Frederikshalds krigshistorie',
#   'Henr. Køhn',
#   'nob',
#   ''],
#  [2012101507085,
#   'Dalai Lama',
#   1988,
#   'Med mennesket for fred',
#   'Lanser',
#   'nob',
#   ''],
#  [2015071308023,
#   'Riverbend',
#   2008,
#   'Bagdad brenner',
#   'Pocketforl.',
#   'nob',
#   'eng'],
#  [2011072008151,
#   'Bruckner, Pascal',
#   2006,
#   'europeiske masochismen =',
#   'Press;Oslo : Press, 2006',
#   'mul',
#   ''],
#  [2015062408088,
#   'Garbo, Gunnar',
#   2002,
#   'Også krig er terror',
#   'G. Garbo',
#   'nob',
#   ''],
#  [2012070206112,
#   'Nöstlinger, Christine',
#   1984,
#   'To uker i mai',
#   'Aschehoug',
#   'nob',
#   'ger'],
#  [2012091708098,
#   'Svedelid, Olov',
#   1985,
#   'Tilbaketoget',
#   'Samlaget',
#   'nno',
#   'swe'],
#  [2013012108083,
#   'Bull-Hansen, Haakon',
#   2008,
#   'I krig for fred',
#   'Kagge',
#   'nob',
#   ''],
#  [2015062908018, 'Christensen, Jan', 2005, 'Oslogjengen', 'Orion', 'nob', ''],
#  [2007062504049,
#   '',
#   1982,
#   'Kirken, krisen og krigen',
#   'Universitetsforlaget',
#   'mul',
#   ''],
#  [2014070306169,
#   '',
#   1989,
#   'Eritrea',
#   'Norsk bonde- og småbrukarlag',
#   'nob',
#   ''],
#  [2008080600098,
#   'Mæland, Jens Olav',
#   1998,
#   'Yrkesetikk for offiserer',
#   'Høyskoleforl.',
#   'nob',
#   ''],
#  [2013011706102,
#   'Butenschøn, Nils A.',
#   2008,
#   'Midtøsten',
#   'Universitetsforlaget',
#   'nob',
#   ''],
#  [2007031501015,
#   'Jungk, Robert',
#   1960,
#   'Stråler fra asken',
#   'Aschehoug',
#   'nob',
#   'ger'],
#  [2013061408057,
#   'Bjørlykke, Oskar Stein',
#   1982,
#   'Fredsdalen',
#   'Samlaget',
#   'nno',
#   ''],
#  [2013041106084,
#   'Austad, Torleiv',
#   1976,
#   'Krig og militærnekting',
#   'Aschehoug',
#   'mul',
#   ''],
#  [2014022624028,
#   'Sundberg, Ulf',
#   1998,
#   'Svenska krig 1521-1814',
#   'Hjalmarson &amp; Högberg',
#   'swe',
#   ''],
#  [2013082806027,
#   'Vettenranta, Soilikki',
#   2005,
#   'De unge og katastrofenyheter',
#   'Abstrakt forlag',
#   'nob',
#   ''],
#  [2014020708029, '', 2006, 'Å være tsjetsjener', 'Humanist', 'nob', 'rus'],
#  [2008011404100,
#   '',
#   1993,
#   'Humøret tok de ikke fra oss',
#   'Grøndahl Dreyer',
#   'nob',
#   ''],
#  [2008012800097,
#   'Bjugn, Sissel Solbjørg',
#   1994,
#   'Ola trudde først!',
#   'Samlaget',
#   'mul',
#   ''],
#  [2011032403027,
#   'Lium, Randi Nygaard',
#   2009,
#   'Håkon Gullvåg',
#   'Labyrinth Press;Trondheim kunstmuseum',
#   'nob',
#   ''],
#  [2015091106017,
#   'Hjelde, Aase',
#   2006,
#   'Journalistikk under terror',
#   'Tapir akademisk forl.',
#   'nob',
#   ''],
#  [2011101208043,
#   'Doctare, Christina',
#   2004,
#   'Hjernestress - kan det ramme meg?',
#   'Noras ark',
#   'nob',
#   'swe'],
#  [2013050606094,
#   'Lunde, Nils Terje',
#   2010,
#   'Norm og situasjon',
#   'Tapir akademisk forl.',
#   'nob',
#   ''],
#  [2009060404085,
#   'Wold, Ragnar',
#   1990,
#   'Slik fikk vi vinger',
#   'Damm;Norbok',
#   'nob',
#   ''],
#  [2013022506038,
#   'Hald, Ingeborg Kringeland',
#   2010,
#   'Albin Prek',
#   'Mangschou',
#   'nob',
#   ''],
#  [2012091308108,
#   '',
#   1972,
#   'Genèvekonvensjonene for sanitetspersonell',
#   'Fabritius',
#   'nob',
#   ''],
#  [2013052724001, 'Øy, Nils E.', 1991, 'Mot Onsøy 1814', 'Munin', 'nob', ''],
#  [2014072406120,
#   'Englund, Peter',
#   1993,
#   'Poltava',
#   'Universitetsforlaget',
#   'nob',
#   'swe'],
#  [2011031005018,
#   'Kove, Torill',
#   2000,
#   'Min bestemor strøk kongens skjorter',
#   'Cappelen',
#   'nob',
#   ''],
#  [2011082608091,
#   'Haagenrud, Grete',
#   2007,
#   'Sofie og Kathrine',
#   'Transit;Oslo : Transit, 2007-    .',
#   'nob',
#   ''],
#  [2011021505024, '', 1965, 'Fakta om Vietnam', 'Pax', 'nob', 'eng'],
#  [2013091838091,
#   '',
#   2004,
#   'Studia',
#   'Bertmark Norge;[Vestby] : Bertmark Norge, 1996-1998',
#   'nob',
#   ''],
#  [2011060806127,
#   'Slapgard, Sigrun',
#   2003,
#   'Krig og løgn',
#   'Gyldendal',
#   'nno',
#   ''],
#  [2010042708061,
#   'Brekke, Torkel',
#   1999,
#   'Religion og vold',
#   'Humanist forl.',
#   'nob',
#   ''],
#  [2016102848561,
#   '',
#   1960,
#   'A.S Norsk varekrigsforsikring av 1938',
#   'Selskapet',
#   'nob',
#   ''],
#  [2008032504012,
#   'Bjørnsen, Bjørn',
#   1995,
#   'Under bomberegnet',
#   'Direktoratet for sivilt beredskap',
#   'nob',
#   '']]

# %% [markdown]
# ### Søk etter sett av ord i clustret
#
# Finn verdien for ord i clusteret med objekt.check_words('o1 o2 o3 ... oN') med opsjonell spesifikasjon av eksponent. Bare list ordene opp med mellomrom, ord som ikke er i clusteret vil heller ikke vises. Alle andre vises med assosiasjonsverdien og sorteres var høy til lav. Tittel på kolonnen gir en påminnelse om ordet listen er kollokert fra.

# %%
objekt.search_words( 'sår krig . , gevær våpen generaler soldater blod fattigdom nød')
# Out:
#                diff
# krig       0.588141
# soldater   0.555052
# våpen      0.554367
# gevær      0.339961
# fattigdom  0.289486
# generaler  0.280019
# ,          0.276059
# .          0.245816
# nød        0.237181
# blod       0.073396
# sår        0.043019

# %% [markdown]
# ## Ser på samforekomster i URNene i target.urn

# %%
Gs ={u:nb.make_network_graph(u, wordbag=list(objekt.difference(aslist=False, top=100).index)) for u in objekt.target_urn}

# %%
Gtot = nx.compose_all([Gs[u] for u in Gs])

# %%
gnl.show_graph(Gs[objekt.target_urn[1]])

# %%
gnl.show_cliques(Gs[objekt.target_urn[1]])
# Out:
# (3, 1) motstand, serbiske, Irak, forsvare, våpen, sårede, amerikanske, arabisk, vestlige, muslimske, angrep, styrker, militær, krigen, Russland, Hitler, krigens, fronten, skutt, Kosovo, makten, Vietnam, Fienden, USA, september, troppene, 1943, Krig, sivile, arrestert, Saddam, soldater, general, sovjetiske, konflikten, fienden, krigsfanger, overleve, Bush, angripe, offiserer, amerikansk, israelske, allierte, sykehus, offisielle, Midtøsten, ordre, arabiske, krig, forsvar, freden, Røde, parter, bomber, forsvaret, fiendens, uskyldige, Serbia, fiende, Hussein, militære, hæren, soldatene, kampen, væpnede, russiske, tyskerne, Europa, Bagdad, angrepet, amerikanerne
#
# (3, 2) kinesiske, USA, utstyr
#
# (3, 3) styrkene, fienden, Europa
#
# (4, 1) motstand, serbiske, Irak, forsvare, våpen, sårede, amerikanske, arabisk, vestlige, muslimske, angrep, styrker, militær, krigen, Russland, Hitler, krigens, fronten, Kosovo, makten, USA, september, Krig, sivile, Saddam, soldater, general, konflikten, fienden, overleve, Bush, angripe, offiserer, amerikansk, israelske, sykehus, offisielle, Midtøsten, ordre, arabiske, krig, forsvar, freden, parter, bomber, forsvaret, fiendens, uskyldige, Serbia, fiende, Hussein, militære, hæren, soldatene, kampen, væpnede, russiske, tyskerne, Europa, Bagdad, angrepet, amerikanerne
#
# (4, 2) offisielle, Røde, september, Vietnam
#
# (4, 3) sivile, 1943, Serbia, Hitler
#
# (5, 1) motstand, serbiske, Irak, forsvare, våpen, amerikanske, arabisk, vestlige, muslimske, angrep, styrker, militær, krigen, Russland, krigens, Hitler, fronten, Kosovo, makten, USA, september, Krig, sivile, soldater, general, konflikten, fienden, overleve, Bush, offiserer, amerikansk, israelske, sykehus, offisielle, Midtøsten, arabiske, krig, forsvar, freden, parter, forsvaret, bomber, uskyldige, Serbia, fiende, hæren, soldatene, militære, tyskerne, væpnede, russiske, Europa, Bagdad, angrepet, amerikanerne
#
# (5, 2) soldatene, fiendens, Hitler, ordre, militære
#
# (6, 1) fienden, angrepet, våpen, krigens, krig, september
#
# (6, 2) motstand, serbiske, Irak, forsvare, våpen, amerikanske, arabisk, vestlige, muslimske, krigen, militær, Kosovo, USA, september, soldater, general, konflikten, fienden, overleve, Bush, amerikansk, angrepet, sykehus, offisielle, Midtøsten, arabiske, krig, freden, forsvar, parter, bomber, forsvaret, Serbia, fiende, hæren, soldatene, væpnede, Europa, Bagdad, makten, amerikanerne
#
# (6, 3) vestlige, angrep, uskyldige, angrepet, arabiske, amerikanske
#
# (7, 1) muslimske, amerikanske, forsvaret, Bush, fiende, arabisk, USA
#
# (7, 2) motstand, serbiske, Irak, amerikanske, vestlige, muslimske, krigen, militær, Kosovo, USA, september, soldater, general, konflikten, overleve, Bush, amerikansk, angrepet, sykehus, offisielle, Midtøsten, arabiske, krig, forsvar, bomber, Serbia, fiende, hæren, soldatene, væpnede, makten, amerikanerne
#
# (8, 1) general, konflikten, motstand, serbiske, overleve, amerikanske, vestlige, muslimske, amerikansk, offisielle, militær, krigen, krig, bomber, Kosovo, makten, Serbia, fiende, USA, hæren, væpnede, angrepet, soldater
#
# (8, 2) Irak, USA, vestlige, muslimske, Midtøsten, arabiske, soldater, forsvar
#
# (9, 1) konflikten, motstand, serbiske, amerikanske, vestlige, offisielle, militær, krigen, krig, bomber, Kosovo, makten, Serbia, USA, angrepet, general
#
# (9, 2) konflikten, motstand, Serbia, hæren, militær, væpnede, offisielle, angrepet, general
#
# (10, 1) konflikten, serbiske, amerikanske, vestlige, offisielle, krigen, krig, bomber, Kosovo, Serbia, USA, angrepet

# %%
gnl.show_community(Gs[objekt.target_urn[1]])
# Out:
# 1 fiendens, bomber, krigsfanger, Saddam, sårede, Hussein, Hitler, militære, soldatene, offiserer, 1943, troppene, allierte, sivile, ordre, soldater
#
# 2 fronten, motstand, serbiske, Fienden, Kosovo, forsvare, Serbia, vestlige, amerikansk, israelske, Europa, styrker, sykehus, makten
#
# 3 konflikten, parter, stridende, hæren, militær, væpnede, Bagdad, krigen, general
#
# 4 forsvaret, forsvar, Bush, Irak, fiende, USA, amerikanske, arabisk, muslimske, arabiske, september, angripe, tyskerne, Krig, kinesiske, Midtøsten, amerikanerne, utstyr, freden
#
# 5 skutt, fienden, overleve, styrkene, våpen, uskyldige, kampen, angrep, angrepet, arrestert, krigens, krig
#
# 6 sovjetiske, Røde, Vietnam, såkalte, russiske, offisielle, Russland

# %%
gnl.show_graph(Gtot)

# %%
Gtt = nb.check_edges(Gtot, weight=7)

# %%
gnl.show_graph(Gtt)

# %%
gnl.show_cliques(Gtt)
# Out:
# (3, 1) motstand, Irak, forsvare, våpen, ne, sårede, arabisk, amerikanske, muslimske, vestlige, angrep, britisk, styrker, kinesiske, krigen, militær, Russland, krigens, kanoner, skutt, svenskene, fronten, Kosovo, palestinske, Vietnam, styrkene, USA, nordmennene, september, troppene, 1943, britiske, kampene, sivile, Saddam, utstyr, soldater, general, sovjetiske, Krigen, Ali, konflikten, britene, fienden, Bush, militært, angripe, islam, offiserer, amerikansk, israelske, angrepet, allierte, lands, tropper, Midtøsten, ordre, arabiske, krig, freden, forsvar, parter, forsvaret, bomber, svenska, såkalte, kampen, Hussein, soldatene, hæren, tyskerne, russiske, militære, Europa, Bagdad, makten, amerikanerne
#
# (3, 2) sovjetiske, fienden, styrker, Hitler
#
# (3, 3) forsvare, Fienden, Byen
#
# (3, 4) fronten, Hitler, amerikanerne
#
# (4, 1) skutt, svenskene, nordmennene, troppene, angrep, kampene, kanoner
#
# (4, 2) Krigen, britene, Bush, Irak, våpen, amerikanske, arabisk, amerikansk, britisk, krigen, militær, arabiske, krigens, krig, kanoner, svenskene, bomber, USA, Hussein, september, kampen, hæren, britiske, Bagdad, angrepet, Saddam
#
# (4, 3) muslimske, vestlige, arabisk, palestinske
#
# (4, 4) forsvaret, britene, styrkene, militært, arabisk, israelske, allierte, britisk, Bagdad, Midtøsten, arabiske
#
# (4, 5) Ali, krigen, Bagdad, sivile, arabiske
#
# (4, 6) britene, hæren, offiserer, britiske, arabiske
#
# (4, 7) svenska, fienden, krig, våpen
#
# (4, 8) Bagdad, våpen, Irak, sivile
#
# (4, 9) arabisk, Hussein, hæren, krigen, makten
#
# (4, 10) muslimske, fienden, islam, krig

# %%
gnl.show_community(Gtt)
# Out:
# 1 un, serbiske, Irak, ne, våpen, amerikanske, krigen, krigens, USA, 1943, britiske, Krig, sivile, Saddam, arrestert, utstyr, soldater, Krigen, Ali, overleve, Bush, bomber, uskyldige, Hussein, tyskerne, Bagdad, makten
#
# 2 konflikten, forsvaret, britene, Kosovo, palestinske, forsvare, styrkene, militært, Serbia, arabisk, såkalte, vestlige, allierte, britisk, Europa, Midtøsten, Skulle, arabiske
#
# 3 Røde, stridende, parter, offisielle, Vietnam, militære, væpnede, amerikansk, lands, kinesiske, militær, War, general
#
# 4 sårede, angrep, styrker, Hitler, Russland, kanoner, skutt, svenskene, nordmennene, troppene, kampene, sovjetiske, krigsfanger, angripe, offiserer, nordmenn, israelske, tropper, ordre, fiende, kampen, hæren, soldatene, russiske, angrepet, amerikanerne
#
# 5 fronten, fienden, motstand, fiendens, forsvar, svenska, islam, september, muslimske, krig, freden
#
# 6 General, Fienden, Byen
