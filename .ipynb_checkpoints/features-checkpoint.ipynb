# %%
import module_update

# %%
import nbpictures as nbp
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image
#import cv2
import numpy as np

# %%
ntnu = nbp.find_urls('Trondheim, vinter')
#ntnu

# %%
nbp.get_metadata_from_url(ntnu[0])
# Out:
# {'Tilgang': 'Tilgang for alle',
#  'Tittel': '250 Trondheim, Skistuen',
#  'Dato': '01.01.1930 til 01.01.1935',
#  'Andre opplysninger': 'Skistua i Bymarka etter gjennoppbyggingen i 1930.\n\nlandskapsfotografi - vinter - snø - vinterlandskap',
#  'Fotograf': 'Schrøder, Alf',
#  'Sted': 'Norge, Sør Trøndelag, Trondheim, Bymarka,Skistua',
#  'Kilde for metadata': 'mavis.nb.no (/TitleWork/key/2067520)',
#  'Medietype': 'bilder',
#  'Varig lenke': '<a href="https://urn.nb.no/URN:NBN:no-nb_digifoto_20150622_00470_bldsa_PK19054" target="_blank">https://urn.nb.no/URN:NBN:no-nb_digifoto_20150622_00470_bldsa_PK19054</a>',
#  '': '<a href="https://www.nb.no/items/d3e162378970aa6b55a00f810db612e1?manifest=https://api.nb.no/catalog/v1/iiif/d3e162378970aa6b55a00f810db612e1/manifest" target="_blank"><img src="https://www.nb.no/content/uploads/2018/08/logo-iiif.png" alt="IIIF Drag-n-drop"></a>'}

# %%
img = nbp.get_picture_from_url(ntnu[0], height=500)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x518 at 0x1EA6DD8B550>

# %%
npimg = np.array(img)

# %%
npimg
# Out:
# array([[ 9,  9,  9, ..., 10, 10, 10],
#        [ 9,  9,  9, ..., 10, 10, 10],
#        [ 9,  9,  9, ..., 10, 10, 10],
#        ...,
#        [10, 10, 10, ..., 11, 11, 11],
#        [10, 10, 10, ..., 11, 11, 11],
#        [10, 10, 10, ..., 11, 11, 11]], dtype=uint8)

# %%
npimg.shape
# Out:
# (598, 894)

# %%
npimg[400:]=10

# %%
Image.fromarray(npimg)
# Out:
# <PIL.Image.Image image mode=L size=894x598 at 0x1EA6DD6E9B0>

# %%
def features_harris(img, param= 0.01):
    #ilename = 'chessboard.jpg'
    #img = cv2.imread(filename)

    #gray = cv2.cvtColor(open_cv_image,cv2.COLOR_BGR2GRAY)
    cvimg = np.array(img)
    gray = np.float32(cvimg)

    dst = cv2.cornerHarris(gray,2,3,0.04)

    #result is dilated for marking the corners, not important
    dst = cv2.dilate(dst,None)

    # Threshold for an optimal value, it may vary depending on the image.
    cvimg[dst>param*dst.max()]=[255]
    return Image.fromarray(cvimg)

# %%
features_harris(img, param=0.005)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-e1be0d6cfb84> in <module>()
# ----> 1 features_harris(img, param=0.005)
#
# <ipython-input-18-53ee4de8c5c7> in features_harris(img, param)
#       7     gray = np.float32(cvimg)
#       8
# ----> 9     dst = cv2.cornerHarris(gray,2,3,0.04)
#      10
#      11     #result is dilated for marking the corners, not important
#
# NameError: name 'cv2' is not defined

# %%
from skimage import data, io, segmentation, color
from skimage.future import graph
import numpy as np


def _weight_mean_color(graph, src, dst, n):
    """Callback to handle merging nodes by recomputing mean color.

    The method expects that the mean color of `dst` is already computed.

    Parameters
    ----------
    graph : RAG
        The graph under consideration.
    src, dst : int
        The vertices in `graph` to be merged.
    n : int
        A neighbor of `src` or `dst` or both.

    Returns
    -------
    data : dict
        A dictionary with the `"weight"` attribute set as the absolute
        difference of the mean color between node `dst` and `n`.
    """

    diff = graph.node[dst]['mean color'] - graph.node[n]['mean color']
    diff = np.linalg.norm(diff)
    return {'weight': diff}


def merge_mean_color(graph, src, dst):
    """Callback called before merging two nodes of a mean color distance graph.

    This method computes the mean color of `dst`.

    Parameters
    ----------
    graph : RAG
        The graph under consideration.
    src, dst : int
        The vertices in `graph` to be merged.
    """
    graph.node[dst]['total color'] += graph.node[src]['total color']
    graph.node[dst]['pixel count'] += graph.node[src]['pixel count']
    graph.node[dst]['mean color'] = (graph.node[dst]['total color'] /
                                     graph.node[dst]['pixel count'])


img = np.array(img)
labels = segmentation.slic(img, compactness=10, n_segments=800)
g = graph.rag_mean_color(img, labels)

labels2 = graph.merge_hierarchical(labels, g, thresh=35, rag_copy=False,
                                   in_place_merge=True,
                                   merge_func=merge_mean_color,
                                   weight_func=_weight_mean_color)

out = color.label2rgb(labels2, img, kind='avg')
out = segmentation.mark_boundaries(out, labels2, (0, 0, 0))
io.imshow(out)
io.show()

# %%
from skimage import data
from skimage.feature import corner_harris, corner_subpix, corner_peaks
from skimage.transform import warp, AffineTransform
from skimage.draw import ellipse


tform = AffineTransform(scale=(1.3, 1.1), rotation=1, shear=0.7,
                        translation=(210, 50))
image = np.array(img) #warp(np.array(img), tform.inverse, output_shape=(350, 350))
rr, cc = ellipse(310, 175, 10, 100)
#image[rr, cc] = 1
#image[180:230, 10:60] = 1
#image[230:280, 60:110] = 1

coords = corner_peaks(corner_harris(image), min_distance=5)
coords_subpix = corner_subpix(image, coords, window_size=13)

fig, ax = plt.subplots()
ax.imshow(image, interpolation='nearest', cmap=plt.cm.gray)
ax.plot(coords[:, 1], coords[:, 0], '.b', markersize=3)
ax.plot(coords_subpix[:, 1], coords_subpix[:, 0], '+r', markersize=15)
ax.axis((0, 350, 350, 0))
plt.show()
plt.tight_layout()

# %%
from skimage import data
from skimage.feature import corner_harris, corner_subpix, corner_peaks
from skimage.transform import warp, AffineTransform
from skimage.draw import ellipse


tform = AffineTransform(scale=(1.3, 1.1), rotation=1, shear=0.7,
                        translation=(210, 50))
image = warp(data.checkerboard(), tform.inverse, output_shape=(350, 350))
rr, cc = ellipse(310, 175, 10, 100)
image[rr, cc] = 1
image[180:230, 10:60] = 1
image[230:280, 60:110] = 1

coords = corner_peaks(corner_harris(image), min_distance=5)
coords_subpix = corner_subpix(image, coords, window_size=13)

fig, ax = plt.subplots()
ax.imshow(image, interpolation='nearest', cmap=plt.cm.gray)
ax.plot(coords[:, 1], coords[:, 0], '.b', markersize=3)
ax.plot(coords_subpix[:, 1], coords_subpix[:, 0], '+r', markersize=15)
ax.axis((0, 350, 350, 0))
plt.show()

# %%
nbp.display_finds(ntnu)
# Out:
# <html><head></head>
#      <body>
#      <table>
#      <tr><td><img src='https://www.nb.no/services/image/resolver/URN:NBN:no-nb_digifoto_20170117_00077_NB_MIT_GNR_09698/full/0,200/0/native.jpg'</td><td><dl><dt>Tilgang</dt><dd>Tilgang for alle</dd> <dt>Tittel</dt><dd>Trondheim. Norges tekniske høiskole.</dd> <dt>Dato</dt><dd>21.12.1946</dd> <dt>Andre opplysninger</dt><dd>NTH, NTNU, universitet
# Påskrift eske : Trondheim
# Påskrift negativ : Trondheim.Norges tekniske høiskole.061. Enerett  Mittet & Co.</dd> <dt>Utgiver</dt><dd>Mittet & Co. AS</dd> <dt>Sted</dt><dd>Norge, Sør Trøndelag, Trondheim, Gløshaugen,Trondheim, Høgskoleringen 1</dd> <dt>Kilde for metadata</dt><dd>mavis.nb.no (/TitleWork/key/627817)</dd> <dt>Medietype</dt><dd>bilder</dd> <dt>Varig lenke</dt><dd><a href="https://urn.nb.no/URN:NBN:no-nb_digifoto_20170117_00077_NB_MIT_GNR_09698" target="_blank">https://urn.nb.no/URN:NBN:no-nb_digifoto_20170117_00077_NB_MIT_GNR_09698</a></dd> <dt></dt><dd><a href="https://www.nb.no/items/97e34c1326ab2e825c08142c9a846268?manifest=https://api.nb.no/catalog/v1/iiif/97e34c1326ab2e825c08142c9a846268/manifest" target="_blank"><img src="https://www.nb.no/content/uploads/2018/08/logo-iiif.png" alt="IIIF Drag-n-drop"></a></dd></dl></td></tr> <tr><td><img src='https://www.nb.no/services/image/resolver/URN:NBN:no-nb_digifoto_20170117_00119_NB_MIT_GNR_09729/full/0,200/0/native.jpg'</td><td><dl><dt>Tilgang</dt><dd>Tilgang for alle</dd> <dt>Tittel</dt><dd>Trondheim. Norges tekniske høiskole.</dd> <dt>Dato</dt><dd>01.01.1900 til 01.01.1950</dd> <dt>Andre opplysninger</dt><dd>NTH, NTNU, universitet
# Påskrift eske : Trondheim
# Påskrift negativ : Trondheim.Norges tekniske høiskole.058.Enerett Mittet & Co.</dd> <dt>Utgiver</dt><dd>Mittet & Co. AS</dd> <dt>Sted</dt><dd>Norge, Sør Trøndelag, Trondheim, Gløshaugen,Trondheim, Høgskoleringen 1</dd> <dt>Kilde for metadata</dt><dd>mavis.nb.no (/TitleWork/key/627915)</dd> <dt>Medietype</dt><dd>bilder</dd> <dt>Varig lenke</dt><dd><a href="https://urn.nb.no/URN:NBN:no-nb_digifoto_20170117_00119_NB_MIT_GNR_09729" target="_blank">https://urn.nb.no/URN:NBN:no-nb_digifoto_20170117_00119_NB_MIT_GNR_09729</a></dd> <dt></dt><dd><a href="https://www.nb.no/items/a37dd586927ba1c5d61b047a98ba1fd9?manifest=https://api.nb.no/catalog/v1/iiif/a37dd586927ba1c5d61b047a98ba1fd9/manifest" target="_blank"><img src="https://www.nb.no/content/uploads/2018/08/logo-iiif.png" alt="IIIF Drag-n-drop"></a></dd></dl></td></tr> <tr><td><img src='https://www.nb.no/services/image/resolver/URN:NBN:no-nb_digifoto_20161110_00124_NB_MIT_GNR_09676/full/0,200/0/native.jpg'</td><td><dl><dt>Tilgang</dt><dd>Tilgang for alle</dd> <dt>Tittel</dt><dd>Trondheim. Norges tekniske høiskole.</dd> <dt>Dato</dt><dd>21.12.1946</dd> <dt>Andre opplysninger</dt><dd>NTNU, skoler, universitet
# Påskrift eske : Trondheim
# Påskrift negativ :Trondheim.Norges tekniske høiskole.062 Enerett Mittet & Co.</dd> <dt>Utgiver</dt><dd>Mittet & Co. AS</dd> <dt>Sted</dt><dd>Norge, Sør Trøndelag, Trondheim, Gløshaugen,Trondheim</dd> <dt>Kilde for metadata</dt><dd>mavis.nb.no (/TitleWork/key/627742)</dd> <dt>Medietype</dt><dd>bilder</dd> <dt>Varig lenke</dt><dd><a href="https://urn.nb.no/URN:NBN:no-nb_digifoto_20161110_00124_NB_MIT_GNR_09676" target="_blank">https://urn.nb.no/URN:NBN:no-nb_digifoto_20161110_00124_NB_MIT_GNR_09676</a></dd> <dt></dt><dd><a href="https://www.nb.no/items/1eb68fb14aabfd88644f0d67c1cff3f2?manifest=https://api.nb.no/catalog/v1/iiif/1eb68fb14aabfd88644f0d67c1cff3f2/manifest" target="_blank"><img src="https://www.nb.no/content/uploads/2018/08/logo-iiif.png" alt="IIIF Drag-n-drop"></a></dd></dl></td></tr> <tr><td><img src='https://www.nb.no/services/image/resolver/URN:NBN:no-nb_digifoto_20170117_00023_NB_MIT_GNR_09690/full/0,200/0/native.jpg'</td><td><dl><dt>Tilgang</dt><dd>Tilgang for alle</dd> <dt>Tittel</dt><dd>Trondheim. Norges tekniske Høiskole.</dd> <dt>Dato</dt><dd>01.01.1900 til 01.01.1950</dd> <dt>Andre opplysninger</dt><dd>NTH, NTNU, universitet
# Påskrift eske : Trondheim
# Påskrift negativ :Trondheim.Norges tekniske Høiskole.04. Mittet & Co.</dd> <dt>Utgiver</dt><dd>Mittet & Co. AS</dd> <dt>Sted</dt><dd>Norge, Sør Trøndelag, Trondheim, Gløshaugen,Trondheim, Høgskoleringen 1</dd> <dt>Kilde for metadata</dt><dd>mavis.nb.no (/TitleWork/key/627778)</dd> <dt>Medietype</dt><dd>bilder</dd> <dt>Varig lenke</dt><dd><a href="https://urn.nb.no/URN:NBN:no-nb_digifoto_20170117_00023_NB_MIT_GNR_09690" target="_blank">https://urn.nb.no/URN:NBN:no-nb_digifoto_20170117_00023_NB_MIT_GNR_09690</a></dd> <dt></dt><dd><a href="https://www.nb.no/items/e9e2df548784a2c1b4bb33868531040d?manifest=https://api.nb.no/catalog/v1/iiif/e9e2df548784a2c1b4bb33868531040d/manifest" target="_blank"><img src="https://www.nb.no/content/uploads/2018/08/logo-iiif.png" alt="IIIF Drag-n-drop"></a></dd></dl></td></tr> <tr><td><img src='https://www.nb.no/services/image/resolver/URN:NBN:no-nb_digifoto_20161110_00121_NB_MIT_GNR_09673/full/0,200/0/native.jpg'</td><td><dl><dt>Tilgang</dt><dd>Tilgang for alle</dd> <dt>Tittel</dt><dd>Trondheim. Norges tekniske Høiskole.</dd> <dt>Dato</dt><dd>01.01.1900 til 01.01.1950</dd> <dt>Andre opplysninger</dt><dd>NTNU, skoler, universitet
# Påskrift eske : Trondheim
# Påskrift negativ : Trondheim.Norges tekniske Høiskole.058 Enerett Mittet & Co.</dd> <dt>Utgiver</dt><dd>Mittet & Co. AS</dd> <dt>Sted</dt><dd>Norge, Sør Trøndelag, Trondheim, Gløshaugen,Trondheim</dd> <dt>Kilde for metadata</dt><dd>mavis.nb.no (/TitleWork/key/627738)</dd> <dt>Medietype</dt><dd>bilder</dd> <dt>Varig lenke</dt><dd><a href="https://urn.nb.no/URN:NBN:no-nb_digifoto_20161110_00121_NB_MIT_GNR_09673" target="_blank">https://urn.nb.no/URN:NBN:no-nb_digifoto_20161110_00121_NB_MIT_GNR_09673</a></dd> <dt></dt><dd><a href="https://www.nb.no/items/1d517f03365d2eed9cc73d4f664f4edd?manifest=https://api.nb.no/catalog/v1/iiif/1d517f03365d2eed9cc73d4f664f4edd/manifest" target="_blank"><img src="https://www.nb.no/content/uploads/2018/08/logo-iiif.png" alt="IIIF Drag-n-drop"></a></dd></dl></td></tr> <tr><td><img src='https://www.nb.no/services/image/resolver/URN:NBN:no-nb_digifoto_20161111_00017_NB_MIT_GNR_09913/full/0,200/0/native.jpg'</td><td><dl><dt>Tilgang</dt><dd>Tilgang for alle</dd> <dt>Tittel</dt><dd>Trondheim. Norges tekniske Høiskole.</dd> <dt>Dato</dt><dd>18.11.1941</dd> <dt>Andre opplysninger</dt><dd>universitet, NTNU, NTH
# Påskrift eske : Trondheim
# Påskrift negativ : Trondheim.Norges tekniske Høiskole.0236.Mittet & Co.</dd> <dt>Utgiver</dt><dd>Mittet & Co. AS</dd> <dt>Sted</dt><dd>Norge, Sør Trøndelag, Trondheim, Gløshaugen,Trondheim</dd> <dt>Kilde for metadata</dt><dd>mavis.nb.no (/TitleWork/key/628802)</dd> <dt>Medietype</dt><dd>bilder</dd> <dt>Varig lenke</dt><dd><a href="https://urn.nb.no/URN:NBN:no-nb_digifoto_20161111_00017_NB_MIT_GNR_09913" target="_blank">https://urn.nb.no/URN:NBN:no-nb_digifoto_20161111_00017_NB_MIT_GNR_09913</a></dd> <dt></dt><dd><a href="https://www.nb.no/items/ed6bac25e698513d5e2557412aa21bf0?manifest=https://api.nb.no/catalog/v1/iiif/ed6bac25e698513d5e2557412aa21bf0/manifest" target="_blank"><img src="https://www.nb.no/content/uploads/2018/08/logo-iiif.png" alt="IIIF Drag-n-drop"></a></dd></dl></td></tr> <tr><td><img src='https://www.nb.no/services/image/resolver/URN:NBN:no-nb_digifoto_20170220_00029_NB_MIT_ENR_00159/full/0,200/0/native.jpg'</td><td><dl><dt>Tilgang</dt><dd>Tilgang for alle</dd> <dt>Tittel</dt><dd>[Trondheim]</dd> <dt>Dato</dt><dd>01.01.1910 til 01.01.1960</dd> <dt>Andre opplysninger</dt><dd>NTH, NTNU, universitet
# Fotograf: ukjent
# Påskrift eske: Div. Oslo
# Påskrift konvolutt: Ubrukte</dd> <dt>Utgiver</dt><dd>Mittet & Co. AS</dd> <dt>Sted</dt><dd>Norge, Sør Trøndelag, Trondheim, Gløshaugen,Trondheim, Høgskoleringen 1</dd> <dt>Kilde for metadata</dt><dd>mavis.nb.no (/TitleWork/key/610224)</dd> <dt>Medietype</dt><dd>bilder</dd> <dt>Varig lenke</dt><dd><a href="https://urn.nb.no/URN:NBN:no-nb_digifoto_20170220_00029_NB_MIT_ENR_00159" target="_blank">https://urn.nb.no/URN:NBN:no-nb_d
